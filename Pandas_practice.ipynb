# %%
import pandas as pd
import numpy as np

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
movies = pd.read_csv('http://bit.ly/imdbratings')
orders = pd.read_csv('http://bit.ly/chiporders', sep='\t')
orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')
stocks = pd.read_csv('http://bit.ly/smallstocks', parse_dates=['Date'])
titanic = pd.read_csv('http://bit.ly/kaggletrain')
ufo = pd.read_csv('http://bit.ly/uforeports', parse_dates=['Time'])

# %% [markdown]
# ## Convert strings to numbers

# %%
df = pd.DataFrame({'col_one':['1.1', '2.2', '3.3'],
                   'col_two':['4.4', '5.5', '6.6'],
                   'col_three':['7.7', '8.8', '-']})
df
# Out:
#   col_one col_two col_three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
df.dtypes
# Out:
# col_one      object
# col_two      object
# col_three    object
# dtype: object

# %%
df.astype({'col_one':'float', 'col_two':'float'}).dtypes
# Out:
# col_one      float64
# col_two      float64
# col_three     object
# dtype: object

# %%
pd.to_numeric(df.col_three, errors='coerce')
# Out:
# 0    7.7
# 1    8.8
# 2    NaN
# Name: col_three, dtype: float64

# %%
df = df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#    col_one  col_two  col_three
# 0      1.1      4.4        7.7
# 1      2.2      5.5        8.8
# 2      3.3      6.6        NaN

# %% [markdown]
# ## Filter a DataFrame by multiple categories

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies[(movies.genre == 'Action' )|(movies.genre == 'Horror') |(movies.genre == 'Fantasy')].head()
# Out:
#     star_rating                                           title  \
# 3           9.0                                 The Dark Knight
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                       Star Wars
# 20          8.7                                      The Matrix
#
#    content_rating   genre  duration  \
# 3           PG-13  Action       152
# 11          PG-13  Action       148
# 12             PG  Action       124
# 19             PG  Action       121
# 20              R  Action       136
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 11  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 19  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 20  [u'Keanu Reeves', u'Laurence Fishburne', u'Car...

# %%
movies[movies.genre.isin(['Action', 'Horror', 'Fantasy'])].head()
# Out:
#     star_rating                                           title  \
# 3           9.0                                 The Dark Knight
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                       Star Wars
# 20          8.7                                      The Matrix
#
#    content_rating   genre  duration  \
# 3           PG-13  Action       152
# 11          PG-13  Action       148
# 12             PG  Action       124
# 19             PG  Action       121
# 20              R  Action       136
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 11  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 19  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 20  [u'Keanu Reeves', u'Laurence Fishburne', u'Car...

# %%
movies[~movies.genre.isin(['Action', 'Horror', 'Fantasy'])].head()
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
# 4          8.9              Pulp Fiction              R  Crime       154
# 5          8.9              12 Angry Men      NOT RATED  Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %% [markdown]
# ## Aggregate by multiple functions: Groupby

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
orders.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
orders.groupby('order_id').item_price.agg(['sum', 'mean', 'count']).head()
# Out:
#             sum    mean  count
# order_id
# 1         11.56   2.890      4
# 2         16.98  16.980      1
# 3         12.67   6.335      2
# 4         21.00  10.500      2
# 5         13.70   6.850      2

# %%
total_price = orders.groupby('order_id').item_price.transform('sum')

# %%
orders['total_price'] = total_price
orders.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39        11.56
# 1                                       [Clementine]        3.39        11.56
# ...

# %%
orders['percent_of_total'] = orders.item_price / orders.total_price
orders.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  total_price  \
# 0                                                NaN        2.39        11.56
# 1                                       [Clementine]        3.39        11.56
# ...

# %% [markdown]
# ## Create a Pivot table

# %%
titanic.pivot_table(index = 'Sex', columns = 'Pclass', values = 'Survived', aggfunc = 'mean')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table(index = 'Sex', columns = 'Pclass', values = 'Survived', aggfunc = 'count')
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %% [markdown]
# ##  Style a DataFrame

# %%
stocks
# Out:
#         Date   Close    Volume Symbol
# 0 2016-10-03   31.50  14070500   CSCO
# 1 2016-10-03  112.52  21701800   AAPL
# 2 2016-10-03   57.42  19189500   MSFT
# 3 2016-10-04  113.00  29736800   AAPL
# 4 2016-10-04   57.24  20085900   MSFT
# 5 2016-10-04   31.35  18460400   CSCO
# 6 2016-10-05   57.64  16726400   MSFT
# 7 2016-10-05   31.59  11808600   CSCO
# 8 2016-10-05  113.05  21453100   AAPL

# %%
format_dict = {'Date':'{:%m/%d/%y}', 'Close':'${:.2f}', 'Volume':'{:,}'}

# %%
stocks.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_ce8fdea2_8515_11ea_aa0c_7c2a318c654e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Close</th>        <th class="col_heading level0 col2" >Volume</th>        <th class="col_heading level0 col3" >Symbol</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce8fdea2_8515_11ea_aa0c_7c2a318c654elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ce8fdea2_8515_11ea_aa0c_7c2a318c654erow0_col0" class="data row0 col0" >10/03/16</td>
#                         <td id="T_ce8fdea2_8515_11ea_aa0c_7c2a318c654erow0_col1" class="data row0 col1" >$31.50</td>
#                         <td id="T_ce8fdea2_8515_11ea_aa0c_7c2a318c654erow0_col2" class="data row0 col2" >14,070,500</td>
# ...

# %%
(stocks.style.format(format_dict)
 .hide_index()
 .highlight_min('Close', color='red')
 .highlight_max('Close', color='lightgreen')
)
# Out:
# <style  type="text/css" >
#     #T_ce974408_8515_11ea_a032_7c2a318c654erow5_col1 {
#             background-color:  red;
#             : ;
#         }    #T_ce974408_8515_11ea_a032_7c2a318c654erow8_col1 {
#             : ;
#             background-color:  lightgreen;
#         }</style><table id="T_ce974408_8515_11ea_a032_7c2a318c654e" ><thead>    <tr>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Close</th>        <th class="col_heading level0 col2" >Volume</th>        <th class="col_heading level0 col3" >Symbol</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ce974408_8515_11ea_a032_7c2a318c654erow0_col0" class="data row0 col0" >10/03/16</td>
#                         <td id="T_ce974408_8515_11ea_a032_7c2a318c654erow0_col1" class="data row0 col1" >$31.50</td>
#                         <td id="T_ce974408_8515_11ea_a032_7c2a318c654erow0_col2" class="data row0 col2" >14,070,500</td>
# ...

# %% [markdown]
# ## Find and remove the duplicated rows

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols, index_col = 'user_id')

# %%
users.shape
# Out:
# (943, 4)

# %%
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
## Mark only the second and the other duplicated rows

# %%
users[users.duplicated()]
# Out:
#          age gender occupation zip_code
# user_id
# 496       21      F    student    55414
# 572       51      M   educator    20003
# 621       17      M    student    60402
# 684       28      M    student    55414
# 733       44      F      other    60630
# 805       27      F      other    20009
# 890       32      M    student    97301

# %%
## Mark all duplicated rows

# %%
users[users.duplicated(keep = False)]
# Out:
#          age gender occupation zip_code
# user_id
# 67        17      M    student    60402
# 85        51      M   educator    20003
# 198       21      F    student    55414
# 350       32      M    student    97301
# 428       28      M    student    55414
# 437       27      F      other    20009
# 460       44      F      other    60630
# 496       21      F    student    55414
# 572       51      M   educator    20003
# 621       17      M    student    60402
# 684       28      M    student    55414
# 733       44      F      other    60630
# 805       27      F      other    20009
# 890       32      M    student    97301

# %%
## drop duplicated rows

# %%
users.drop_duplicates(keep ='first').shape
# Out:
# (936, 4)

# %%
## drop only certain duplicated criteria

# %%
users.drop_duplicates(subset = ['age', 'zip_code']).shape
# Out:
# (927, 4)

# %% [markdown]
# ## Merge Practice

# %% [markdown]
# There are actually four types of joins supported by the Pandas merge function. Here's how they are described by the documentation:
#
# * inner: use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys
# * outer: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically
# * left: use only keys from left frame, similar to a SQL left outer join; preserve key order
# * right: use only keys from right frame, similar to a SQL right outer join; preserve key order
# * The default is the "inner join".
#
# It's easiest to understand the different types by looking at some simple examples:

# %%
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})

# %%
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# ## Inner Join

# %% [markdown]
# it includes only the intersection

# %%
pd.merge(A, B, how = 'inner') # default
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# ## Outer Join

# %% [markdown]
# it includes the union

# %%
pd.merge(A, B, how = 'outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# ## Left Join

# %% [markdown]
# Include all observations found in A:

# %%
pd.merge(A, B, how = 'left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# ## Right Join

# %% [markdown]
# Include all observations found in B:

# %%
pd.merge(A, B, how = 'right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L
